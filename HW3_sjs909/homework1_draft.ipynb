# %%
from __future__ import print_function
import json
import os
# read line input arguments
import sys
try:
    import urllib2 as urllib
except ImportError:
    import urllib.request as urllib

url = 'http://bustime.mta.info/api/siri/vehicle-monitoring.json?key=d075b0b2-c4ba-41e9-ba9d-40a5719b66a6&VehicleMonitoringDetailLevel=calls&LineRef=B52'

print(url)
response = urllib.urlopen(url)
MTAdata = response.read().decode("utf-8")
#use the json.loads method to obtain a dictionary representation of the responose string 
MTAdata = json.loads(MTAdata)
#[0]['MonitoredVehicleJourney']
# Out:
# http://bustime.mta.info/api/siri/vehicle-monitoring.json?key=d075b0b2-c4ba-41e9-ba9d-40a5719b66a6&VehicleMonitoringDetailLevel=calls&LineRef=B52

# %%
for i in range(busNum):
    if MTAdata.get('OnwardCall') == '':
        Stop_Status ='N/a'
        Stop_Name = 'N/a'
    else:
        Stop_Status = MTAdata['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][i]['MonitoredVehicleJourney']['OnwardCalls']['OnwardCall'][0]['Extensions']['Distances']['PresentableDistance']
        Stop_Name = MTAdata['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][1]['MonitoredVehicleJourney']['OnwardCalls']['OnwardCall'][i]['StopPointName']
        lat = MTAdata['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][i]['MonitoredVehicleJourney']['VehicleLocation']['Latitude']
        long = MTAdata['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][i]['MonitoredVehicleJourney']['VehicleLocation']['Longitude']
    print(str(lat) + str(long) + str(Stop_Name)+ " is " + str(Stop_Status))
# Out:
# 40.686179-73.970092JORALEMON ST/COURT ST is at stop
# 40.692471-73.990557CADMAN PLZ W/MONTAGUE ST is at stop
# 40.686567-73.947324CADMAN PZ W/TILLARY ST is approaching
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-308-4d6ef6e8c95b> in <module>()
#       5     else:
#       6         Stop_Status = MTAdata['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][i]['MonitoredVehicleJourney']['OnwardCalls']['OnwardCall'][0]['Extensions']['Distances']['PresentableDistance']
# ----> 7         Stop_Name = MTAdata['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][1]['MonitoredVehicleJourney']['OnwardCalls']['OnwardCall'][i]['StopPointName']
#       8         lat = MTAdata['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][i]['MonitoredVehicleJourney']['VehicleLocation']['Latitude']
# ...

# %%
busNum = len(MTAdata['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'])
for i in range(busNum):
    if MTAdata.get('OnwardCalls') == '':
        Stop_Status ='N/a'
        Stop_Name = 'N/a'
    Stop_Status = (MTAdata['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][i]['MonitoredVehicleJourney']['OnwardCalls']['OnwardCall'][0]['Extensions']['Distances']['PresentableDistance'])
    Stop_Name = MTAdata['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][i]['MonitoredVehicleJourney']['OnwardCalls']['OnwardCall'][1]['StopPointName']
    lat = MTAdata['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][i]['MonitoredVehicleJourney']['VehicleLocation']['Latitude']
    long = MTAdata['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][i]['MonitoredVehicleJourney']['VehicleLocation']['Longitude']
    print(str(lat) + str(long) + str(Stop_Name)+ " is " + str(Stop_Status))
# Out:
# 40.686179-73.970092GREENE AV/VANDERBILT AV is at stop
# 40.692471-73.990557CADMAN PLZ W/MONTAGUE ST is at stop
# 40.686567-73.947324GATES AV/NOSTRAND AV is approaching
# 40.688849-73.927597GATES AV/RALPH AV is approaching
# 40.688059-73.978862FULTON ST/LAFAYETTE AV is approaching
# 40.695894-73.915786GATES AV/CENTRAL AV is approaching
# 40.696224-73.991048ADAMS ST/BKLYN SUPREME CRT is approaching
# 40.685693-73.95507GATES AV/CLASSON AV is < 1 stop away
# 40.689072-73.925699GATES AV/MALCOLM X BL is < 1 stop away
# 40.694147-73.917511GATES AV/KNICKERBOCKER AV is < 1 stop away
# 40.690601-73.985191FULTON ST/FLATBUSH AV EXT is < 1 stop away

# %%
busNum = len(MTAdata['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'])
for i in range(busNum):
   Stop_Status = (MTAdata['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][i]['MonitoredVehicleJourney']['OnwardCalls']['OnwardCall'][0]['Extensions']['Distances']['PresentableDistance'])
    Stop_Name = MTAdata['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][i]['MonitoredVehicleJourney']['OnwardCalls']['OnwardCall'][1]['StopPointName']
    lat = MTAdata['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][i]['MonitoredVehicleJourney']['VehicleLocation']['Latitude']
    long = MTAdata['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][i]['MonitoredVehicleJourney']['VehicleLocation']['Longitude']
    print(str(lat) + str(long) + str(Stop_Name)+ " is " + str(Stop_Status))
# Out:
# 40.686179-73.970092GREENE AV/VANDERBILT AV is at stop
# 40.692471-73.990557CADMAN PLZ W/MONTAGUE ST is at stop
# 40.686567-73.947324GATES AV/NOSTRAND AV is approaching
# 40.688849-73.927597GATES AV/RALPH AV is approaching
# 40.688059-73.978862FULTON ST/LAFAYETTE AV is approaching
# 40.695894-73.915786GATES AV/CENTRAL AV is approaching
# 40.696224-73.991048ADAMS ST/BKLYN SUPREME CRT is approaching
# 40.685693-73.95507GATES AV/CLASSON AV is < 1 stop away
# 40.689072-73.925699GATES AV/MALCOLM X BL is < 1 stop away
# 40.694147-73.917511GATES AV/KNICKERBOCKER AV is < 1 stop away
# 40.690601-73.985191FULTON ST/FLATBUSH AV EXT is < 1 stop away

# %%
MTAdata['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][5]['MonitoredVehicleJourney']['OnwardCalls']
# Out:
# {'OnwardCall': [{'ExpectedArrivalTime': '2018-09-25T11:10:33.098-04:00',
#    'Extensions': {'Distances': {'CallDistanceAlongRoute': 3125.5,
#      'DistanceFromCall': 76.2,
#      'PresentableDistance': 'approaching',
#      'StopsFromCall': 0}},
#    'StopPointName': 'GREENE AV/GRAND AV',
#    'StopPointRef': 'MTA_307551'},
#   {'ExpectedArrivalTime': '2018-09-25T11:11:43.940-04:00',
#    'Extensions': {'Distances': {'CallDistanceAlongRoute': 3364.21,
#      'DistanceFromCall': 314.91,
#      'PresentableDistance': '1 stop away',
#      'StopsFromCall': 1}},
#    'StopPointName': 'GREENE AV/CLASSON AV',
#    'StopPointRef': 'MTA_307552'},
#   {'ExpectedArrivalTime': '2018-09-25T11:12:48.740-04:00',
#    'Extensions': {'Distances': {'CallDistanceAlongRoute': 3595.03,
#      'DistanceFromCall': 545.72,
#      'PresentableDistance': '2 stops away',
#      'StopsFromCall': 2}},
#    'StopPointName': 'FRANKLIN AV/GREENE AV',
#    'StopPointRef': 'MTA_307553'},
# ...

# %%
if MTAdata.get('OnwardCalls') == '':
    print('NaN')

# %%
busNum = len(MTAdata['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'])
for i in range(busNum): 
    print(MTAdata['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][i]['MonitoredVehicleJourney']['OnwardCalls']['OnwardCall'])
# Out:
# [{'StopPointName': 'GATES AV/CENTRAL AV', 'StopPointRef': 'MTA_307689', 'Extensions': {'Distances': {'StopsFromCall': 0, 'DistanceFromCall': 0.0, 'PresentableDistance': 'at stop', 'CallDistanceAlongRoute': 7388.47}}}, {'StopPointName': 'GATES AV/WILSON AV', 'StopPointRef': 'MTA_307690', 'ExpectedArrivalTime': '2018-09-25T11:10:22.462-04:00', 'Extensions': {'Distances': {'StopsFromCall': 1, 'DistanceFromCall': 203.23, 'PresentableDistance': '1 stop away', 'CallDistanceAlongRoute': 7591.7}}}, {'StopPointName': 'GATES AV/KNICKERBOCKER AV', 'StopPointRef': 'MTA_307691', 'ExpectedArrivalTime': '2018-09-25T11:10:36.563-04:00', 'Extensions': {'Distances': {'StopsFromCall': 2, 'DistanceFromCall': 409.11, 'PresentableDistance': '2 stops away', 'CallDistanceAlongRoute': 7797.59}}}, {'StopPointName': 'PALMETTO ST/IRVING AV', 'StopPointRef': 'MTA_304415', 'ExpectedArrivalTime': '2018-09-25T11:12:04.618-04:00', 'Extensions': {'Distances': {'StopsFromCall': 3, 'DistanceFromCall': 710.11, 'Presenta
# ...

# %%
busNum = len(MTAdata['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'])
for i in range(busNum):    
    #Stop_Status = MTAdata['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][i]['MonitoredVehicleJourney']['OnwardCalls']['OnwardCall'][i]['Extensions']['Distances']['PresentableDistance']
    Stop_Status = MTAdata['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][i]['MonitoredVehicleJourney']['OnwardCalls']['OnwardCall'][1]
    #Stop_Name = MTAdata['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][i]['MonitoredVehicleJourney']['OnwardCalls']['OnwardCall'][1]['StopPointName']
    #    Stop_Name = MTAdata['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][i]['MonitoredVehicleJourney']['OnwardCalls']['OnwardCall'][i]['StopPointName']
    lat = MTAdata['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][i]['MonitoredVehicleJourney']['VehicleLocation']['Latitude']
    long = MTAdata['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][i]['MonitoredVehicleJourney']['VehicleLocation']['Longitude']
    print(str(lat) + str(long) + str(Stop_Name)+ " is " + str(Stop_Status))
# Out:
# 40.694126-73.917531GREENE AV/CUMBERLAND ST is {'StopPointName': 'GATES AV/WILSON AV', 'StopPointRef': 'MTA_307690', 'ExpectedArrivalTime': '2018-09-25T11:10:22.462-04:00', 'Extensions': {'Distances': {'StopsFromCall': 1, 'DistanceFromCall': 203.23, 'PresentableDistance': '1 stop away', 'CallDistanceAlongRoute': 7591.7}}}
# 40.686904-73.944342GREENE AV/CUMBERLAND ST is {'StopPointName': 'GATES AV/THROOP AV', 'StopPointRef': 'MTA_307679', 'ExpectedArrivalTime': '2018-09-25T11:11:31.057-04:00', 'Extensions': {'Distances': {'StopsFromCall': 1, 'DistanceFromCall': 256.05, 'PresentableDistance': '1 stop away', 'CallDistanceAlongRoute': 5103.34}}}
# 40.688876-73.927379GREENE AV/CUMBERLAND ST is {'StopPointName': 'GATES AV/RALPH AV', 'StopPointRef': 'MTA_307901', 'ExpectedArrivalTime': '2018-09-25T11:11:37.747-04:00', 'Extensions': {'Distances': {'StopsFromCall': 1, 'DistanceFromCall': 277.98, 'PresentableDistance': '1 stop away', 'CallDistanceAlongRoute': 6572.3}}}
# ...

# %%
status = len(MTAdata['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][1]['MonitoredVehicleJourney']['OnwardCalls']['OnwardCall'])

# %%
for i in range(busNum):
    print((MTAdata['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][i]['MonitoredVehicleJourney']['OnwardCalls']['OnwardCall'][0]['Extensions']['Distances']['PresentableDistance']))
# Out:
# at stop
# at stop
# approaching
# approaching
# approaching
# < 1 stop away
# < 1 stop away
# < 1 stop away
# < 1 stop away
# < 1 stop away
# < 1 stop away
# < 1 stop away

# %%
(MTAdata['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][i]['MonitoredVehicleJourney']['OnwardCalls']['OnwardCall'][0]['Extensions']['Distances']['PresentableDistance'])
# Out:
# '< 1 stop away'

# %%
MTAdata['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][10]['MonitoredVehicleJourney']['OnwardCalls']['OnwardCall'][0]
# Out:
# {'ExpectedArrivalTime': '2018-09-25T10:57:37.157-04:00',
#  'Extensions': {'Distances': {'CallDistanceAlongRoute': 7931.22,
#    'DistanceFromCall': 276.45,
#    'PresentableDistance': '< 1 stop away',
#    'StopsFromCall': 0}},
#  'StopPointName': 'JORALEMON ST/COURT ST',
#  'StopPointRef': 'MTA_302434'}

# %%
for i in range(busNum):
    print((MTAdata['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][i]['MonitoredVehicleJourney']['OnwardCalls']['OnwardCall']))
# Out:
# [{'StopPointName': 'GREENE AV/GRAND AV', 'StopPointRef': 'MTA_307551', 'ExpectedArrivalTime': '2018-09-25T10:55:07.995-04:00', 'Extensions': {'Distances': {'StopsFromCall': 0, 'DistanceFromCall': 9.94, 'PresentableDistance': 'at stop', 'CallDistanceAlongRoute': 3125.5}}}, {'StopPointName': 'GREENE AV/CLASSON AV', 'StopPointRef': 'MTA_307552', 'ExpectedArrivalTime': '2018-09-25T10:55:43.694-04:00', 'Extensions': {'Distances': {'StopsFromCall': 1, 'DistanceFromCall': 248.65, 'PresentableDistance': '1 stop away', 'CallDistanceAlongRoute': 3364.21}}}, {'StopPointName': 'FRANKLIN AV/GREENE AV', 'StopPointRef': 'MTA_307553', 'ExpectedArrivalTime': '2018-09-25T10:56:48.494-04:00', 'Extensions': {'Distances': {'StopsFromCall': 2, 'DistanceFromCall': 479.47, 'PresentableDistance': '2 stops away', 'CallDistanceAlongRoute': 3595.03}}}, {'StopPointName': 'GATES AV/FRANKLIN AV', 'StopPointRef': 'MTA_307674', 'ExpectedArrivalTime': '2018-09-25T10:57:46.703-04:00', 'Extensions': {'Distances': {'Sto
# ...

# %%
status = len(MTAdata['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][1]['MonitoredVehicleJourney']['OnwardCalls']['OnwardCall'])
for i in range(busNum):

    print(MTAdata['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][i]['MonitoredVehicleJourney']['OnwardCalls']['OnwardCall'][i]['Extensions']['Distances'])
# Out:
# {'StopsFromCall': 0, 'DistanceFromCall': 9.94, 'PresentableDistance': 'at stop', 'CallDistanceAlongRoute': 3125.5}
# {'StopsFromCall': 1, 'DistanceFromCall': 262.78, 'PresentableDistance': '1 stop away', 'CallDistanceAlongRoute': 7193.37}
# {'StopsFromCall': 2, 'DistanceFromCall': 468.68, 'PresentableDistance': '2 stops away', 'CallDistanceAlongRoute': 2098.42}
# {'StopsFromCall': 3, 'DistanceFromCall': 689.96, 'PresentableDistance': '3 stops away', 'CallDistanceAlongRoute': 1233.08}
# {'StopsFromCall': 4, 'DistanceFromCall': 1014.71, 'PresentableDistance': '0.6 miles away', 'CallDistanceAlongRoute': 3373.21}
# {'StopsFromCall': 5, 'DistanceFromCall': 1375.05, 'PresentableDistance': '0.9 miles away', 'CallDistanceAlongRoute': 4864.43}
# {'StopsFromCall': 6, 'DistanceFromCall': 1418.51, 'PresentableDistance': '0.9 miles away', 'CallDistanceAlongRoute': 7797.59}
# ...

# %%
MTAdata['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][0]['MonitoredVehicleJourney']['VehicleLocation']
# Out:
# {'Latitude': 40.688493, 'Longitude': -73.930576}

# %%
MTAdata['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][7]['MonitoredVehicleJourney']['VehicleLocation']
# Out:
# {'Latitude': 40.692371, 'Longitude': -73.989013}

# %%
busNum = len(MTAdata['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'])
currentBus = MTAdata['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity']

# %%
print(currentBus)
# Out:
# [{'RecordedAtTime': '2018-09-25T09:41:48.000-04:00', 'MonitoredVehicleJourney': {'JourneyPatternRef': 'MTA_B520052', 'OperatorRef': 'MTA NYCT', 'Bearing': 48.075138, 'VehicleRef': 'MTA NYCT_7275', 'SituationRef': [], 'DestinationName': 'RIDGEWOOD TERM via GATES', 'OnwardCalls': {'OnwardCall': [{'StopPointName': 'PALMETTO ST/WYCKOFF AV', 'StopPointRef': 'MTA_801117', 'ExpectedArrivalTime': '2018-09-25T09:42:20.014-04:00', 'Extensions': {'Distances': {'StopsFromCall': 0, 'DistanceFromCall': 0.0, 'PresentableDistance': 'at stop', 'CallDistanceAlongRoute': 8248.54}}}]}, 'LineRef': 'MTA NYCT_B52', 'DirectionRef': '0', 'OriginRef': 'MTA_307175', 'DestinationRef': 'MTA_801117', 'FramedVehicleJourneyRef': {'DataFrameRef': '2018-09-25', 'DatedVehicleJourneyRef': 'MTA NYCT_FP_D8-Weekday-SDon-053700_B52_122'}, 'Monitored': True, 'VehicleLocation': {'Longitude': -73.911268, 'Latitude': 40.69932}, 'MonitoredCall': {'StopPointName': 'PALMETTO ST/WYCKOFF AV', 'ExpectedArrivalTime': '2018-09-25T09:4
# ...

# %%
MTAdata['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][0]['MonitoredVehicleJourney']['VehicleLocation']['Longitude']
# Out:
# -73.911268

# %%
lat = MTAdata['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][i]['MonitoredVehicleJourney']['VehicleLocation']['Latitude']

# %%
long = MTAdata['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][0]['MonitoredVehicleJourney']['VehicleLocation']['Longitude']

# %%
for i in range(busNum):
    lat = MTAdata['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][i]['MonitoredVehicleJourney']['VehicleLocation']['Latitude']
    long = MTAdata['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][i]['MonitoredVehicleJourney']['VehicleLocation']['Longitude']
    print("Bus " + str(i) + " the latitude is " + str(lat) + " and the longitude is " + str(long))
# Out:
# for bus 0 the latitude is 40.69932 and the longitude is -73.911268
# for bus 1 the latitude is 40.686509 and the longitude is -73.947832
# for bus 2 the latitude is 40.688533 and the longitude is -73.98005
# for bus 3 the latitude is 40.689443 and the longitude is -73.92251
# for bus 4 the latitude is 40.686392 and the longitude is -73.968272
# for bus 5 the latitude is 40.699131 and the longitude is -73.911438
# for bus 6 the latitude is 40.689851 and the longitude is -73.983362
# for bus 7 the latitude is 40.687505 and the longitude is -73.939083
# for bus 8 the latitude is 40.693982 and the longitude is -73.917672
# for bus 9 the latitude is 40.68555 and the longitude is -73.956305
# for bus 10 the latitude is 40.685741 and the longitude is -73.954656
# for bus 11 the latitude is 40.689832 and the longitude is -73.983317
# for bus 12 the latitude is 40.686571 and the longitude is -73.966776
# for bus 13 the latitude is 40.686345 and the longitude is -73.94925
# ...

# %%
for i in range(busNum):
    print(MTAdata['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][i]['MonitoredVehicleJourney']['VehicleLocation'])
# Out:
# {'Longitude': -73.911268, 'Latitude': 40.69932}
# {'Longitude': -73.947832, 'Latitude': 40.686509}
# {'Longitude': -73.98005, 'Latitude': 40.688533}
# {'Longitude': -73.92251, 'Latitude': 40.689443}
# {'Longitude': -73.968272, 'Latitude': 40.686392}
# {'Longitude': -73.911438, 'Latitude': 40.699131}
# {'Longitude': -73.983362, 'Latitude': 40.689851}
# {'Longitude': -73.939083, 'Latitude': 40.687505}
# {'Longitude': -73.917672, 'Latitude': 40.693982}
# {'Longitude': -73.956305, 'Latitude': 40.68555}
# {'Longitude': -73.954656, 'Latitude': 40.685741}
# {'Longitude': -73.983317, 'Latitude': 40.689832}
# {'Longitude': -73.966776, 'Latitude': 40.686571}
# {'Longitude': -73.94925, 'Latitude': 40.686345}
# {'Longitude': -73.964453, 'Latitude': 40.686844}
# {'Longitude': -73.90994, 'Latitude': 40.700595}
# {'Longitude': -73.989211, 'Latitude': 40.69612}

# %%
MTAdata
# Out:
# {'Siri': {'ServiceDelivery': {'ResponseTimestamp': '2018-09-25T09:42:20.014-04:00',
#    'SituationExchangeDelivery': [],
#    'VehicleMonitoringDelivery': [{'ResponseTimestamp': '2018-09-25T09:42:20.014-04:00',
#      'ValidUntil': '2018-09-25T09:43:20.014-04:00',
#      'VehicleActivity': [{'MonitoredVehicleJourney': {'Bearing': 48.075138,
#         'DestinationName': 'RIDGEWOOD TERM via GATES',
#         'DestinationRef': 'MTA_801117',
#         'DirectionRef': '0',
#         'FramedVehicleJourneyRef': {'DataFrameRef': '2018-09-25',
#          'DatedVehicleJourneyRef': 'MTA NYCT_FP_D8-Weekday-SDon-053700_B52_122'},
#         'JourneyPatternRef': 'MTA_B520052',
#         'LineRef': 'MTA NYCT_B52',
#         'Monitored': True,
#         'MonitoredCall': {'ExpectedArrivalTime': '2018-09-25T09:42:21.014-04:00',
#          'ExpectedDepartureTime': '2018-09-25T09:42:21.014-04:00',
#          'Extensions': {'Distances': {'CallDistanceAlongRoute': 8248.54,
# ...

# %%
MTAdata['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][0]['MonitoredVehicleJourney']['OnwardCalls']
# Out:
# {'OnwardCall': [{'ExpectedArrivalTime': '2018-09-25T09:42:20.014-04:00',
#    'Extensions': {'Distances': {'CallDistanceAlongRoute': 8248.54,
#      'DistanceFromCall': 0.0,
#      'PresentableDistance': 'at stop',
#      'StopsFromCall': 0}},
#    'StopPointName': 'PALMETTO ST/WYCKOFF AV',
#    'StopPointRef': 'MTA_801117'}]}

# %%
MTAdata['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][i]['MonitoredVehicleJourney']['OnwardCalls']['OnwardCall'][0]['Extensions']['Distances']['PresentableDistance']
# Out:
# '< 1 stop away'

# %%
MTAdata['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][1]['MonitoredVehicleJourney']['OnwardCalls']
# Out:
# {'OnwardCall': [{'ExpectedArrivalTime': '2018-09-25T09:42:20.014-04:00',
#    'Extensions': {'Distances': {'CallDistanceAlongRoute': 3903.29,
#      'DistanceFromCall': 2.71,
#      'PresentableDistance': 'at stop',
#      'StopsFromCall': 0}},
#    'StopPointName': 'GATES AV/MARCY AV',
#    'StopPointRef': 'MTA_304211'},
#   {'ExpectedArrivalTime': '2018-09-25T09:44:14.950-04:00',
#    'Extensions': {'Distances': {'CallDistanceAlongRoute': 4183.96,
#      'DistanceFromCall': 283.38,
#      'PresentableDistance': '1 stop away',
#      'StopsFromCall': 1}},
#    'StopPointName': 'GATES AV/NOSTRAND AV',
#    'StopPointRef': 'MTA_304212'},
#   {'ExpectedArrivalTime': '2018-09-25T09:45:52.537-04:00',
#    'Extensions': {'Distances': {'CallDistanceAlongRoute': 4497.03,
#      'DistanceFromCall': 596.45,
#      'PresentableDistance': '2 stops away',
#      'StopsFromCall': 2}},
#    'StopPointName': 'GATES AV/BEDFORD AV',
#    'StopPointRef': 'MTA_304213'},
# ...
